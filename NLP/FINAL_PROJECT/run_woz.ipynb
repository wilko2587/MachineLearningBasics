# %%
# initialise TPU on colab

try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)

    import os
    import sys
    os.chdir('./drive/MyDrive/NLP_Final/') # change directory to wherever your collab code is

    #%% [code]
    ! pip install -qqq "torchvision" "torch>=1.6, <1.9" "torchmetrics>=0.3" "ipython[notebook]" "pytorch-lightning>=1.3" "torchtext"
    ! pip install -qqq cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.8-cp37-cp37m-linux_x86_64.whl

    ## Install dependencies
    ! pip install -qqq wget
    ! apt-get -qqq install sox libsndfile1 ffmpeg
    ! pip install -qqq unidecode
    ! pip install -qqq matplotlib>=3.3.2
    ! pip install tranformers=2.8
    ! pip install datasets
    ! pip install -U nltk
    ! pip install meteor_score
    
    ## Install NeMo
    BRANCH = 'r1.6.1'
    ! python -m pip install -qqq git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]

    ! mkdir configs
    ! wget -P configs/ https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/examples/asr/conf/config.yaml

    datapath = './'
    print("Running with Colab setup.")
    tpu_cores = 8
    gpu_cores = None
except(ModuleNotFoundError):
    print('Initialising non-colab set-up...')
    tpu_cores=None
    gpu_cores=None
    datapath = './'

import os
import woz
print("cwd: {}".format(os.getcwd()))
print("datapath: {}".format(datapath))
print('done.')
# Out:
# Mounted at /content/drive
# ERROR: Invalid requirement: 'tranformers=2.8'
# Hint: = is not a valid operator. Did you mean == ?
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.63.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.2)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (5.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.63.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.3.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# ERROR: Could not find a version that satisfies the requirement meteor_score (from versions: none)
# ERROR: No matching distribution found for meteor_score
# mkdir: cannot create directory ‘configs’: File exists
# --2022-03-15 19:42:44--  https://raw.githubusercontent.com/NVIDIA/NeMo/r1.6.1/examples/asr/conf/config.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4040 (3.9K) [text/plain]
# Saving to: ‘configs/config.yaml.7’
#
# config.yaml.7       100%[===================>]   3.95K  --.-KB/s    in 0.001s
#
# 2022-03-15 19:42:44 (3.15 MB/s) - ‘configs/config.yaml.7’ saved [4040/4040]
#
# Running with Colab setup.
# cwd: /content/drive/MyDrive/NLP_Final
# datapath: ./
# done.

# %%
woz.main('restaurant', model_path='gpt2', gen_mode=1)
# Out:
# [11022, 580, 580]
# [11022, 580, 580, 580, 580]
# total parameters =  124439808
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# max_len: 96 total: 511
# ref: I've heard good things about the lucky star. Need a reservation? [END]
# Prd: am looking for a restaurant. I would like something cheap that has Chinese food. [USER] I am looking for a restaurant. I would like something cheap that has Chinese food. [USER] I am looking for a restaurant. I would like something cheap that has Chinese food. [USER] I am looking for a restaurant. I
#
# ref: Yes, could you make a reservation for 1 at 20:00 on Saturday? [END]
# Prd: sorry, but I'm not sure if I can get a reservation. [USER] I'm sorry, but I'm not sure if I can get a reservation. [USER] I'm sorry, but I'm not sure if I can get a reservation. [USER] I'm sorry, but I'm not sure if I can get a
#
# ref: Your booking was successful. The table will be reserved for 15 minutes. Reference number is : FDLFKTZM . [END]
# Prd: I'm not sure. [USER] Yes, could you make a reservation for 1 at 20:00 on Saturday? [SYSTEM] No, I'm not sure. [USER] Yes, could you make a reservation for 1 at 20:00 on Saturday? [SYSTEM] No, I'm not sure.
#
# ref: Thank you so much for your help! [END]
# Prd: was successful. The table will be reserved for 15 minutes. Reference number is : FDLFKTZM. [PASSWORD] Your booking was successful. The table will be reserved for 15 minutes. Reference number is : FDLFKTZM. [PASSWORD_ID
#
# ref: You're welcome. Thank you! Have a good day now! [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER
#
# ref: Thanks, you too. Goodbye. [END]
# Prd: I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a programmer. I'm a
#
# ref: Thank you for using Cambridge TownInfo centre. Good-bye [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER]
#
# ref: Eraina is a European restaurant in the centre area. Their address is St. Michael's Church Trinity Street City Centre and phone number 01223 355166. [END]
# Prd: to find an expensive restaurant and serves european food. Can i also have the address, phone number and its area.?
#
# ref: thank you goodbye [END]
# Prd: is a European restaurant in the centre area. Their address is St. Michael's Church Trinity Street City Centre and phone number 01223 355166. [PASSWORD] Eraina is a European restaurant in the centre area. Their address is St. Michael
#
# ref: Thank you and good bye [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [
#
# ref: There are results matching your query. Would you like Mexican, Italian, Chinese, or Indian? [END]
# Prd: am looking for a restaurant that is in the expensive price range and in the south part of town. [USER] I am looking for a restaurant that is in the expensive price range and in the south part of town. [SYSTEM] I am looking for a restaurant that is in the expensive price range and in the
#
# ref: Let's go with Italian food. [END]
# Prd: [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD] [PASSWORD
#
# ref: Frankie and Bennys is an expensive Italian eatery in the south part of town. Would you like any additional information about this restaurant? [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER]
#
# ref: address and phone number [END]
# Prd: and Bennys is an expensive Italian eatery in the south part of town. Would you like any additional information about this restaurant? [SYSTEM] Frankie and Bennys is an expensive Italian eatery in the south part of town. Would you like any additional information about this restaurant? [USER]
#
# ref: The address is Cambridge Leisure Park Clifton Way Cherry Hinton. The phone number is 01223 412430. [END]
# Prd: and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number [USER] address and phone number
#
# ref: Thank you, goodbye. [END]
# Prd: address is Cambridge Leisure Park Clifton Way Cherry Hinton. The phone number is 01223 412430. [PASSWORD] The address is Cambridge Leisure Park Clifton Way Cherry Hinton. The phone number is 01223 412430. [PASSWORD_ID
#
# ref: You're welcome, goodbye. [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER
#
# ref: I'm sorry. There is no matching restaurant. Would you like to try a different food type or area? [END]
# Prd: looking for a place to stay for a few days. [USER] I'm looking for a place to stay for a few days. [USER] I'm looking for a place to stay for a few days. [USER] I'm looking for a
#
# ref: Hmm... let me think. Let's try maybe something italian instead. [END]
# Prd: sorry. There is no matching restaurant. Would you like to try a different food type or area? [USER] I'm sorry. There is no matching restaurant. Would you like to try a different food type or area? [USER] I'm sorry. There is no matching restaurant. Would you like to
#
# ref: There are nine Italian restaurants in the centre of town! Are you looking for an Italian restaurant in any particular price range? [END]
# Prd: [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [USER] [
#
# ref: Which of those nine has the best ratings? Can I please have the address and postcode. [END]
# Prd: [PASSWORD] [PASSWORD_NUMBER] [PASSWORD_NAME] [PASSWORD_PASSWORD] [PASSWORD_PASSWORD_NUMBER] [PASSWORD_PASSWORD_PASSWORD_NUMBER] [PASSWORD
#
# ref: I recommend Caffe Uno - it's very nice. They're at 32 Bridge Street City Centre, cb21uj. Can I help with anything else? [END]
# Prd: of those nine has the best system? [USER] Which of those nine has the best system? [SYSTEM] Which of those nine has the best system? [USER] Which of those nine has the best system? [SYSTEM] Which of those nine has the best system? [USER] Which of
#
# ref: No, that's all. Thanks. [END]
# Prd: not sure what to do. [USER] I'm not sure what to do. [USER] I'm not sure what to do. [USER] I'm not sure what to do. [USER] I'm not sure what to do
#
# ref: Thank you! Goodbye. [END]
# Prd: that's all. [USER] No, that's all. [SYSTEM] No, that's all. [USER] No, that's all. [SYSTEM] No, that's all. [USER] No, that's all. [SYSTEM] No, that's all. [USER] No, that's all.
